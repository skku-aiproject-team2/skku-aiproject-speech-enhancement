# %%
# choose 10% of files in train/noisy and train/clean and move them to dataset_mini/train/noisy and dataset_mini/train/clean
# file name should be the same in noisy and clean

import os
import random
import shutil


src_noisy = '../dataset/train/noisy'
src_clean = '../dataset/train/clean'
dst_noisy = '../dataset_mini_5percent/train/noisy'
dst_clean = '../dataset_mini_5percent/train/clean'

os.makedirs(dst_noisy, exist_ok=True)
os.makedirs(dst_clean, exist_ok=True)

noisy_files = os.listdir(src_noisy)
clean_files = os.listdir(src_clean)

random.shuffle(noisy_files)

for i in range(int(len(noisy_files) * 0.05)):
    file = noisy_files[i]
    shutil.copy(os.path.join(src_noisy, file), os.path.join(dst_noisy, file))
    shutil.copy(os.path.join(src_clean, file), os.path.join(dst_clean, file))
    
    # print from and to
    print(os.path.join(src_noisy, file), os.path.join(dst_noisy, file))
    print(os.path.join(src_clean, file), os.path.join(dst_clean, file))
    print('')
# Out:
# ../dataset/train/noisy/p335_411.wav ../dataset_mini_5percent/train/noisy/p335_411.wav
# ../dataset/train/clean/p335_411.wav ../dataset_mini_5percent/train/clean/p335_411.wav
#
# ../dataset/train/noisy/p260_101.wav ../dataset_mini_5percent/train/noisy/p260_101.wav
# ../dataset/train/clean/p260_101.wav ../dataset_mini_5percent/train/clean/p260_101.wav
#
# ../dataset/train/noisy/p314_174.wav ../dataset_mini_5percent/train/noisy/p314_174.wav
# ../dataset/train/clean/p314_174.wav ../dataset_mini_5percent/train/clean/p314_174.wav
#
# ../dataset/train/noisy/p264_242.wav ../dataset_mini_5percent/train/noisy/p264_242.wav
# ../dataset/train/clean/p264_242.wav ../dataset_mini_5percent/train/clean/p264_242.wav
#
# ../dataset/train/noisy/p285_291.wav ../dataset_mini_5percent/train/noisy/p285_291.wav
# ../dataset/train/clean/p285_291.wav ../dataset_mini_5percent/train/clean/p285_291.wav
#
# ../dataset/train/noisy/p293_093.wav ../dataset_mini_5percent/train/noisy/p293_093.wav
# ...

# %%
src_noisy = '../dataset/valid/noisy'
src_clean = '../dataset/valid/clean'
dst_noisy = '../dataset_mini_5percent/valid/noisy'
dst_clean = '../dataset_mini_5percent/valid/clean'

os.makedirs(dst_noisy, exist_ok=True)
os.makedirs(dst_clean, exist_ok=True)

noisy_files = os.listdir(src_noisy)
clean_files = os.listdir(src_clean)

random.shuffle(noisy_files)

for i in range(int(len(noisy_files) * 0.1)):
    file = noisy_files[i]
    shutil.copy(os.path.join(src_noisy, file), os.path.join(dst_noisy, file))
    shutil.copy(os.path.join(src_clean, file), os.path.join(dst_clean, file))
    
    # print from and to
    print(os.path.join(src_noisy, file), os.path.join(dst_noisy, file))
    print(os.path.join(src_clean, file), os.path.join(dst_clean, file))
    print('')
# Out:
# ../dataset/valid/noisy/p232_199.wav ../dataset_mini_5percent/valid/noisy/p232_199.wav
# ../dataset/valid/clean/p232_199.wav ../dataset_mini_5percent/valid/clean/p232_199.wav
#
# ../dataset/valid/noisy/p257_348.wav ../dataset_mini_5percent/valid/noisy/p257_348.wav
# ../dataset/valid/clean/p257_348.wav ../dataset_mini_5percent/valid/clean/p257_348.wav
#
# ../dataset/valid/noisy/p232_155.wav ../dataset_mini_5percent/valid/noisy/p232_155.wav
# ../dataset/valid/clean/p232_155.wav ../dataset_mini_5percent/valid/clean/p232_155.wav
#
# ../dataset/valid/noisy/p232_041.wav ../dataset_mini_5percent/valid/noisy/p232_041.wav
# ../dataset/valid/clean/p232_041.wav ../dataset_mini_5percent/valid/clean/p232_041.wav
#
# ../dataset/valid/noisy/p257_428.wav ../dataset_mini_5percent/valid/noisy/p257_428.wav
# ../dataset/valid/clean/p257_428.wav ../dataset_mini_5percent/valid/clean/p257_428.wav
#
# ../dataset/valid/noisy/p257_252.wav ../dataset_mini_5percent/valid/noisy/p257_252.wav
# ...
